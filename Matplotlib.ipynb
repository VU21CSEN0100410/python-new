# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100410/python-new/blob/module4/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([0,7])
ypoints= np.array([0,300])
plt.plot( xpoints, ypoints )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,5])
ypoints= np.array([1,200])
plt.plot( xpoints, ypoints )
plt.show()

# %% [markdown]
# PLOT WITHOUT LINE

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,5])
ypoints= np.array([1,200])
plt.plot( xpoints, ypoints,'o' )
plt.show()

# %% [markdown]
# MULTIPLE POINTS

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,3,5,7])
ypoints= np.array([1,165,53,260])
plt.plot( xpoints, ypoints )
plt.show()

# %% [markdown]
# DEFAULT X POINTS

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6,1,10,4,11])
plt.plot( ypoints )
plt.show()

# %% [markdown]
# MATPLOTLIB MARKERS

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6,1])
plt.plot( ypoints, marker='o' )
plt.show()

# %% [markdown]
# FORMAT STRINGS fmt

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,8,2,9,6])
plt.plot( ypoints,'o:r' )
plt.show()

# %% [markdown]
# MARKER SIZE

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,2,9,6,1])
plt.plot( ypoints, marker='o',ms=25 )
plt.show()

# %% [markdown]
# MARKER COLOR

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,3,2,9,6,1])
plt.plot( ypoints, marker='o',ms=15,mec='r' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([1,2,3,2,5,7,1])
plt.plot( ypoints, marker='o',ms=15,mfc='pink' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([2,9,6,1])
plt.plot( ypoints, marker='o',ms=25,mec='r',mfc='#4CAF50' )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,7,9,6,1])
plt.plot( ypoints, marker='o',ms=20,mec='#4CAF50',mfc='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([6,2,9,6])
plt.plot( ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([5,2,9,6])
plt.plot( ypoints,ls='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([8,7,9,6,1])
plt.plot( ypoints, linestyle=':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([6,6,6,6,4,5,4,3])
plt.plot( ypoints, color='purple')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints= np.array([2,3,6,2,8,6,1])
plt.plot( ypoints,linewidth='20')
plt.show()

# %% [markdown]
# MULTIPLE LINES

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([1, 10, 2, 9])
y2 = np.array([8, 11, 2, 6])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([60, 65, 70, 75, 80, 85, 90, 95])
y = np.array([150, 160, 170, 180, 190, 200, 210, 220])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([36, 24, 14, 26])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([25, 35, 25, 15])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([36, 24, 14, 26])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([36, 24, 14, 26])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
myexplode = [0.3, 0.1, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([36, 24, 14, 26])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
myexplode = [0, 0.2, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow= True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([36, 24, 14, 26])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
mycolors = ["green", "orange", "#b4b4b4", "black"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([24, 36, 26, 14])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([24, 36, 26, 14])
mylabels = ["kitkat", "dairy milk", "snickers", "milkybar"]
plt.pie(y, labels = mylabels)
plt.legend(title = "Four chocolates:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([10, 8, 2, 6])
plt.bar(x,y)
plt.show()

# %%
x = ["candy", "Marshmallow"]
y = [500,1000]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([10, 8, 2, 6])
plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([10, 8, 2, 6])
plt.bar(x, y, color = "#b4b4b4")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([10, 8, 2, 6])
plt.bar(x, y, color = "orange")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([6, 8, 2, 6])
plt.bar(x, y, color = "b")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([6, 8, 2, 10])
plt.bar(x, y, width = 0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 2, 6])

plt.barh(x, y, height=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,6,7,8,9,9,10,11,12])
y = np.array([99,98,98,97,96,95,94,93,92])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 9, 2, 3])
y = np.array([3, 8, 1, 7])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1,2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(8, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([1, 3, 2, 3])
y = np.array([10, 20, 32, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 5, 6, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2, 1, 8, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 4, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 0, 3])
y = np.array([10 ,8 ,11 ,3])

plt.subplot(1, 1, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 13, 40])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("INCOME")

plt.show()
